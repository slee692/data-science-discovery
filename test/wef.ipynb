# %%
import pandas as pd

# %%
df = pd.read_csv('gpa.csv')
df
# Out:
#        Year    Term YearTerm Subject  Number                   Course Title  \
# 0      2020  Spring  2020-sp     AAS     100   Intro Asian American Studies
# 1      2020  Spring  2020-sp     AAS     100   Intro Asian American Studies
# 2      2020  Spring  2020-sp     AAS     100   Intro Asian American Studies
# 3      2020  Spring  2020-sp     AAS     100   Intro Asian American Studies
# 4      2020  Spring  2020-sp     AAS     100   Intro Asian American Studies
# ...     ...     ...      ...     ...     ...                            ...
# 53928  2010  Summer  2010-su    STAT     410  Statistics and Probability II
# 53929  2010  Summer  2010-su    STAT     440    Statistical Data Management
# 53930  2010  Summer  2010-su     TAM     212          Introductory Dynamics
# 53931  2010  Summer  2010-su     TAM     251   Introductory Solid Mechanics
# 53932  2010  Summer  2010-su     TAM     335   Introductory Fluid Mechanics
#
# ...

# %%
grades = df.groupby("Subject").agg("sum").reset_index()
grades
# Out:
#     Subject     Year  Number    A+      A     A-     B+      B    B-    C+  \
# 0       AAS   360617   23290   771   2094    812    517    526   246   135
# 1       ABE   265957   44357   315   2556    800    703    902   240   127
# 2      ACCY  4553856  829676  7416  23142  15600  14839  13614  5703  2798
# 3       ACE  1777080  241702  3523  13421   5040   4316   6859  2610  1627
# 4      ACES   286071   16537   889   1838    259    119    272    68    67
# ..      ...      ...     ...   ...    ...    ...    ...    ...   ...   ...
# 158      UP   578226  104655  1063   3559   2037   1241   1358   487   248
# 159      VB     8040    2489     0    212      6      6    120     1     0
# 160     VCM    74447   24157   302   1321     29     49   1036    20    18
# 161      VM   187402   56460     0   1825      8      0   5861     1     0
# 162    YDSH    26176    3560    40     91     81     32     40    12     6
#
#         C    C-   D+    D   D-    F    W
# ...

# %%
a = df.groupby(["Subject", "Number"]).agg("sum").reset_index()
a["Total"] = a["A+"] + a["A"] + a["A-"]
a
# Out:
#      Subject  Number    Year   A+     A   A-   B+    B   B-  C+    C  C-  D+  \
# 0        AAS     100  255897  629  1449  553  353  359  156  77   91  31  16
# 1        AAS     105    2018   10     7    3    2    0    0   0    1   0   0
# 2        AAS     120   40228   26   136  108   93  104   49  36   32  11   6
# 3        AAS     200    2017    7     7    3    1    0    2   1    0   0   0
# 4        AAS     211    4029    3    20   12    2    4    3   2    1   0   3
# ...      ...     ...     ...  ...   ...  ...  ...  ...  ...  ..  ...  ..  ..
# 3986      VM     610   20146    0   123    0    0  614    0   0  463   0   0
# 3987      VM     611   16132    0   110    0    0  574    0   0  316   0   0
# 3988      VM     620   10079    0   221    8    0   40    1   0    2   0   0
# 3989    YDSH     220   12083   25    36   51   16   13    7   2    0   0   0
# 3990    YDSH     320   14093   15    55   30   16   27    5   4    4   2   0
#
#        D  D-   F   W  Total
# ...

# %%
a = df.groupby("Major").agg("count")
a
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r2/fn43xny535g24kffxv2c977m0000gn/T/ipykernel_1420/4141200086.py in <module>
# ----> 1 a = df.groupby("Major").agg("count")
#       2 a
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/frame.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7624         # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7625         # "Union[bool, NoDefault]"; expected "bool"
# -> 7626         return DataFrameGroupBy(
#    7627             obj=self,
#    7628             keys=by,
#
# ...

# %%
df.mean()
# Out:
# Several      13.096429
# A Few         5.789286
# Many         30.085714
# A Couple      6.001786
# Dozens       35.421429
# Some         12.419643
# Scores Of    78.790741
# dtype: float64

# %%
df = df[df.Several == 5]
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/r2/fn43xny535g24kffxv2c977m0000gn/T/ipykernel_27290/1555264570.py in <module>
# ----> 1 df = df[df["Several"] == 5]
#       2 df
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in __getitem__(self, key)
#     940
#     941         elif key_is_scalar:
# --> 942             return self._get_value(key)
#     943
#     944         if is_hashable(key):
#
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/series.py in _get_value(self, label, takeable)
#    1049
#    1050         # Similar to Index.get_value, but we do not fall back to positional
# -> 1051         loc = self.index.get_loc(label)
#    1052         return self.index._get_values_for_loc(self, loc, label)
#    1053
#
# ...

# %%
df.Several += 6
df.mean()
# Out:
# Several      19.096429
# A Few         5.789286
# Many         30.085714
# A Couple      6.001786
# Dozens       35.421429
# Some         12.419643
# Scores Of    78.790741
# dtype: float64

# %%
df["Scores Of"] *= 3
df.mean()
# Out:
# Several       19.096429
# A Few          5.789286
# Many          30.085714
# A Couple       6.001786
# Dozens        35.421429
# Some          12.419643
# Scores Of    236.372222
# dtype: float64

# %%
df = df.append({"Some" : 1000000}, ignore_index=True)
df
# Out:
#     Several  A Few   Many  A Couple  Dozens       Some  Scores Of
# 0       5.0    5.0   10.0       4.0    12.0       15.0       25.0
# 1       5.0    3.0   12.0       2.0    24.0        4.0       35.0
# 2       5.0    4.0   15.0       2.0    30.0       10.0       50.0
# 3       5.0    3.0   10.0       2.0    24.0        6.0       30.0
# 4       4.0    3.0   20.0       2.0    36.0       12.0      200.0
# 5      15.0    8.0   30.0      12.0    80.0       20.0      100.0
# 6       5.0    3.0    7.0       6.0    20.0       10.0      100.0
# 7      15.0    7.0   68.0       2.0    56.0        8.0       20.0
# 8       3.0    5.0   20.0      10.0    50.0        5.0       80.0
# 9       3.0    5.0    7.0      10.0    50.0       20.0      100.0
# 10      7.0    4.0   25.0       2.0    24.0        4.0        2.0
# 11      6.0    3.0   50.0       2.0    36.0       15.0      100.0
# 12     50.0    5.0  100.0      15.0    30.0       20.0      500.0
# ...

# %%
df.Some.mean()
# Out:
# 12.419642857142858
